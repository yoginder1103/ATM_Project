# %%
import random
import sys

class ATM():
    def __init__(self, name, account_number, balance, pin):
        self.name=name
        self.account_number=account_number
        self.balance=balance
        self.pin=pin
        
    def account_detail(self):
        P=int(input("Enter Your Pin"))
        if P == pin:
            print("\n----------ACCOUNT DETAIL----------")
            print(f"Account Holder: {self.name.upper()}")
            print(f"Account Number: {self.account_number}")    
            print(f"Avilable Balance: {self.balance}")
            
        else:
            print("Your pin is not correct")
            
    def deposit(self,amount):
        P=int(input("Enter Your Pin"))
        if P == pin:
            self.amount=amount
            self.balance=self.balance+self.amount
            print("Current account balance is : ",self.balance)
        else:
            print("Your pin is not correct")
        
        
    def withdraw(self,amount):
        P=int(input("Enter Your Pin"))
        if P == pin:
            self.amount=amount
            if self.amount>self.balance:
                print(f"your balance is {self.balance} only")
            else:
                self.balance=self.balance - self.amount
                print(f"{self.amount} is withdrawal successful. \nCurrent account balance is :",self.balance)
        else:
            print("Your pin is not correct")
            
    def check_balance(self):
        P=int(input("Enter Your Pin"))
        if P == pin:
            print("Available balance is : ",self.balance)
        else:
            print("Your pin is not correct")
                
        
    def transaction(self):
        print("   TRANSACTION    \n*************** \nMenu: \nSelect Transaction \n1.Account Detail      2.Check Balance \n3.Deposit             4.Withdraw \n5.Exit            \n***************")
        while True:
            option=int(input("Enter the value 1 to 5 : "))
            if option==1:
                atm.account_detail()
            elif option==2:
                atm.check_balance()
            elif option==3:
                amount=int(input("Enter the amount how much you want to deposit : "))
                atm.deposit(amount)
            elif option==4:
                amount=int(input("Enter the amount how much you want to Withdraw : "))
                atm.withdraw(amount)
            elif option==5:
                print(f"""
                Printout the receipt
          ==================================
          Transaction is complete.
          Transaction number is : {random.randint(100,10000)}
          Account Holder Name is : {self.name.upper()}
          Account Number is : {self.account_number}
          Available balance is : {self.balance}
       
       **********Thank You***********
       """)
                break
            else:
                print("Enter the valid number between 1 to 5, Only!")
                
            

            
print("~~~~~~~WELCOME TO BANK OF SBI~~~~~~~~")
print("*********ACCOUNT CREATION********")
name = input("Enter the name of account holder: ")
pin=int(input("Enter yor generate_pin:"))
account_number = int(input("Enter your account number: "))
balance = 0
print("Congratulations! Account created successfully and generate_pin")
          
atm= ATM(name, account_number, balance, pin)          
          
while True:
        Transaction=input("Do you want to do transaction?select(y or n) : ")
        if Transaction == "y" :
            atm.transaction()
            
        elif Transaction == "n" :
            print("""------------------------------------------------
                          Thanks for choosing us your bank visit us again!
                          ------------------------------------------------
                          """)
            break
        
        else:
            print("Wrong command! Enter only 'y' either 'n'.")
# Out:
# ~~~~~~~WELCOME TO BANK OF SBI~~~~~~~~
# *********ACCOUNT CREATION********
# Enter the name of account holder: Yoginder
# Enter yor generate_pin:1319
# Enter your account number: 4569
# Congratulations! Account created successfully and generate_pin
# Do you want to do transaction?select(y or n) : y
#    TRANSACTION
# ***************
# Menu:
# Select Transaction
# 1.Account Detail      2.Check Balance
# 3.Deposit             4.Withdraw
# 5.Exit
# ***************
# Enter the value 1 to 5 : 1
# Enter Your Pin1319
#
# ----------ACCOUNT DETAIL----------
# Account Holder: YOGINDER
# Account Number: 4569
# Avilable Balance: 0
# Enter the value 1 to 5 : 3
# Enter the amount how much you want to deposit : 4000
# Enter Your Pin1319
# Current account balance is :  4000
# Enter the value 1 to 5 : 2
# Enter Your Pin1319
# Available balance is :  4000
# Enter the value 1 to 5 : 4
# Enter the amount how much you want to Withdraw : 1560
# Enter Your Pin1319
# 1560 is withdrawal successful.
# Current account balance is : 2440
# Enter the value 1 to 5 : 5
#
#                 Printout the receipt
#           ==================================
#           Transaction is complete.
#           Transaction number is : 8632
#           Account Holder Name is : YOGINDER
#           Account Number is : 4569
#           Available balance is : 2440
#
#        **********Thank You***********
#
# Do you want to do transaction?select(y or n) : n
# ------------------------------------------------
#                           Thanks for choosing us your bank visit us again!
#                           ------------------------------------------------
